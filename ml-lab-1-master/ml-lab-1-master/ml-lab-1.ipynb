# %% [markdown]
# Author: Ling Lee

# %%
# paste code from README.md to display versions and run cell
import sys

print("Python version:", sys.version)

 

import pandas as pd

print("pandas version:", pd.__version__)

 

import matplotlib

print("matplotlib version:", matplotlib.__version__)

 

import numpy as np

print("NumPy version:", np.__version__)

 

import scipy as sp

print("SciPy version:", sp.__version__)

 

import IPython

print("IPython version:", IPython.__version__)

 

import sklearn

print("scikit-learn version:", sklearn.__version__)

 

import yellowbrick

print("yellowbrick version:", yellowbrick.__version__)
# Out:
# Python version: 3.9.12 (main, Apr  4 2022, 05:22:27) [MSC v.1916 64 bit (AMD64)]
# pandas version: 1.4.2
# matplotlib version: 3.5.1
# NumPy version: 1.19.2
# SciPy version: 1.7.3
# IPython version: 8.2.0
# scikit-learn version: 1.0.2
# yellowbrick version: 1.3

# %%
# run this cell to list conda environments
# !conda info --envs
# Out:
# # conda environments:
# #
#                          C:\Users\lingl\anaconda3
#                          C:\Users\lingl\anaconda3\envs\100_Days_of_Coding
#                          C:\Users\lingl\anaconda3\envs\CoffeeMachine
#                          C:\Users\lingl\anaconda3\envs\DOM
#                          C:\Users\lingl\anaconda3\envs\Day-16-start
#                          C:\Users\lingl\anaconda3\envs\Day-28-Pomodoro
#                          C:\Users\lingl\anaconda3\envs\Day-29-Password-Manager
#                          C:\Users\lingl\anaconda3\envs\Day-30-errors_exceptions_json
#                          C:\Users\lingl\anaconda3\envs\DiceGame
#                          C:\Users\lingl\anaconda3\envs\Enumerate&Generators
#                          C:\Users\lingl\anaconda3\envs\SimonGame
#                          C:\Users\lingl\anaconda3\envs\day-17-start
#                          C:\Users\lingl\anaconda3\envs\day-18-start
#                          C:\Users\lingl\anaconda3\envs\day-19
#                          C:\Users\lingl\anaconda3\envs\day-20
#                          C:\Users\lingl\anaconda3\envs\day-22
#                          C:\Users\lingl\anaconda3\envs\day-23
#                          C:\Users\lingl\anaconda3\envs\day-24-reading-and-writing
#                          C:\Users\lingl\anaconda3\envs\day-25-pandas
#                          C:\Users\lingl\anaconda3\envs\day-26-listcomprehension
#                          C:\Users\lingl\anaconda3\envs\day-27-tkinter
#                          C:\Users\lingl\anaconda3\envs\day-31-flashcardapp
#                          C:\Users\lingl\anaconda3\envs\day-55-higher-lower-game
#                          C:\Users\lingl\anaconda3\envs\day-56-my-personal-site
#                          C:\Users\lingl\anaconda3\envs\day-57-Jinja
#                          C:\Users\lingl\anaconda3\envs\day-57-jinja-project
#                          C:\Users\lingl\anaconda3\envs\day-58-bootstrap
#                          C:\Users\lingl\anaconda3\envs\day-59-blog
#                          C:\Users\lingl\anaconda3\envs\day-60-POST-requests-flask-html-forms
#                          C:\Users\lingl\anaconda3\envs\day-61-Flask-WTForms
#                          C:\Users\lingl\anaconda3\envs\day-61-Flask-WTForms3
#                          C:\Users\lingl\anaconda3\envs\day-62-coffe&wifi
#                          C:\Users\lingl\anaconda3\envs\day-62-coffee-and-wifi
#                          C:\Users\lingl\anaconda3\envs\day-62-coffee-and-wifi2
#                          C:\Users\lingl\anaconda3\envs\day-63-databases
#                          C:\Users\lingl\anaconda3\envs\day-64-top-10-movies
#                          C:\Users\lingl\anaconda3\envs\day-65-web-design-school
#                          C:\Users\lingl\anaconda3\envs\day-66-REST
#                          C:\Users\lingl\anaconda3\envs\day-67-blogpart3
#                          C:\Users\lingl\anaconda3\envs\day-68-authentication-with-flask
#                          C:\Users\lingl\anaconda3\envs\day-69-blog-addingusers
#                          C:\Users\lingl\anaconda3\envs\day-70-blog-addingusers
#                          C:\Users\lingl\anaconda3\envs\day-72-AggregateAndMergeDataWithPandas
#                          C:\Users\lingl\anaconda3\envs\day-72-data-visualization-matplotlib
#                          C:\Users\lingl\anaconda3\envs\day-72-data-visualization-with-matplotlib
#                          C:\Users\lingl\anaconda3\envs\day-73-aggregate-and-merge-data-pandas
#                          C:\Users\lingl\anaconda3\envs\day-74-GoogleTrendsData-ResamplingAndVisualizingTimeSeries
#                          C:\Users\lingl\anaconda3\envs\day-75-plotlycharts-google-play-store-app-analytics
#                          C:\Users\lingl\anaconda3\envs\day-76-computation-with-numpy-and-n-dimensional-arrays
#                          C:\Users\lingl\anaconda3\envs\day-77-seaborn-and-linear-regression
#                          C:\Users\lingl\anaconda3\envs\day1-9
#                          C:\Users\lingl\anaconda3\envs\day32-smtplib
#                          C:\Users\lingl\anaconda3\envs\day33-API
#                          C:\Users\lingl\anaconda3\envs\day34-API-quizzlet
#                          C:\Users\lingl\anaconda3\envs\day35-sendSMS
#                          C:\Users\lingl\anaconda3\envs\day36stocknews
#                          C:\Users\lingl\anaconda3\envs\day37habit_tracker
#                          C:\Users\lingl\anaconda3\envs\day38workout_tracking
#                          C:\Users\lingl\anaconda3\envs\day39_flight_deal_finder
#                          C:\Users\lingl\anaconda3\envs\day71-data-exploration-with-pandas
#                          C:\Users\lingl\anaconda3\envs\day_45_beautifulsoup
#                          C:\Users\lingl\anaconda3\envs\day_46_spotify_playlist
#                          C:\Users\lingl\anaconda3\envs\day_46_spotify_playlist2
#                          C:\Users\lingl\anaconda3\envs\day_47_amazon_price_tracker
#                          C:\Users\lingl\anaconda3\envs\day_48_selenium
#                          C:\Users\lingl\anaconda3\envs\day_49_automating_job_applications_on_linkedin
#                          C:\Users\lingl\anaconda3\envs\day_50_tinder_swiping_bot
#                          C:\Users\lingl\anaconda3\envs\day_51_twitter_complain_Bot
#                          C:\Users\lingl\anaconda3\envs\day_52_instagram_follower_bot
#                          C:\Users\lingl\anaconda3\envs\day_53_data_entry_job_automation
#                          C:\Users\lingl\anaconda3\envs\day_54_flask
#                          C:\Users\lingl\anaconda3\envs\dynamicarrayimplementation
# base                  *  C:\Users\lingl\anaconda3\envs\ensf-ml
#                          C:\Users\lingl\anaconda3\envs\ensf592
#                          C:\Users\lingl\anaconda3\envs\ensf592\envs\ensf611
#                          C:\Users\lingl\anaconda3\envs\fay-61-Flask-WTForms2
#                          C:\Users\lingl\anaconda3\envs\hirst_painting
#                          C:\Users\lingl\anaconda3\envs\introduction_to_css
#                          C:\Users\lingl\anaconda3\envs\introduction_to_css_2
#                          C:\Users\lingl\anaconda3\envs\introduction_to_html
#                          C:\Users\lingl\anaconda3\envs\jQuery
#                          C:\Users\lingl\anaconda3\envs\openpyxl_playground
#                          C:\Users\lingl\anaconda3\envs\pandas_playground
#                          C:\Users\lingl\anaconda3\envs\section13advancedJSandDOMmanipulation
#                          C:\Users\lingl\anaconda3\envs\sqlite
